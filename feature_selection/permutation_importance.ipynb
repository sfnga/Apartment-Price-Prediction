# %% [markdown]
# # Важность признаков на основе перестановки

# %% [markdown]
# ## 1 Импорт библиотек, инициализация глобальных констант

# %% [markdown]
# ### 1.1 Импорт библиотек

# %%
import pandas as pd
import numpy as np
import warnings
from matplotlib import pyplot as plt
import seaborn as sns
from colorama import Fore, Back, Style
from typing import Tuple, List, Callable, Any
from tqdm import tqdm

from sklearn.utils import check_random_state
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_absolute_percentage_error

import lightgbm as lgb
from lightgbm import log_evaluation

warnings.simplefilter('ignore')
pd.set_option('display.max_columns', None)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ### 1.2 Инициализация констант

# %%
TARGET_NAME = 'Цена_квм'
TEST_SIZE = 0.15
RANDOM_STATE = 42

# %% [markdown]
# ## 2 Подготовка данных

# %%
df = pd.read_csv('/kaggle/input/avito-final/houseprices_final.csv')
df.loc[df['Тип_дома'] == 'монолитнокирпичный',
       'Тип_дома'] = 'монолитно-кирпичный'
metros = pd.read_csv('/kaggle/input/avito-final/metro_coords.csv')
df.head()
# Out:
#            ID                                             Ссылка       Цена  \
# 0  2636072348  https://avito.ru//moskva/kvartiry/3-k._kvartir...   33000000
# 1  2626697262  https://avito.ru//moskva/kvartiry/3-k._kvartir...   39000000
# 2  2658691692  https://avito.ru//moskva/kvartiry/3-k._kvartir...   22500000
# 3  2515435010  https://avito.ru//moskva/kvartiry/3-k._kvartir...   17900000
# 4  1972516369  https://avito.ru//moskva/kvartiry/10_i_bolee-k...  525000000
#
#          Дата                                Адрес  Этаж Количество_комнат  \
# 0  2022-12-02    Москва, Ленинградское шоссе, 69к2  18.0                 3
# 1  2022-12-03           Москва, Ходынская улица, 2  13.0                 3
# 2  2022-12-05     Москва, Аминьевское ш., 4Дк3литБ   9.0                 3
# 3  2022-12-05   Москва, Севастопольский пр-т, 13к2   5.0                 3
# 4  2022-12-05  Москва, Пресненская набережная, 6с2  59.0       10 и больше
#
#   Балкон_или_лоджия     Тип_комнат  Общая_площадь  Жилая_площадь  \
# 0            балкон  изолированные           73.2            NaN
# 1               NaN  изолированные           73.7           50.0
# 2            лоджия  изолированные           69.3           43.9
# 3            лоджия  изолированные           62.5           45.0
# 4               NaN  изолированные          941.7            NaN
#
#    Площадь_кухни  Высота_потолков      Санузел           Ремонт    Тип_дома  \
# 0           16.0              NaN          NaN     дизайнерский  монолитный
# 1           15.0              NaN  совмещенный     дизайнерский  монолитный
# 2            5.7              3.0   раздельный  требует ремонта  монолитный
# 3            7.0              2.8  совмещенный             евро   панельный
# 4           20.0              NaN          NaN    косметический  монолитный
#
#    Год_постройки  Этажей_в_доме  Пассажирский_лифт  Грузовой_лифт  \
# 0            NaN           20.0                  0              0
# 1            NaN           44.0                  0              0
# 2         2022.0           28.0                  2              2
# 3         1979.0            9.0                  1              0
# 4         2010.0           60.0                  1              0
#
#            Метро_1        Метро_2               Метро_3  \
# 0      Беломорская  Речной вокзал             Планерная
# 1  Улица 1905 года        Беговая           Белорусская
# 2      Аминьевская      Давыдково  Мичуринский проспект
# 3         Крымская  Верхние Котлы           Нагатинская
# 4    Деловой центр    Выставочная         Международная
#
#    Расстояние_до_метро_1  Расстояние_до_метро_2  Расстояние_до_метро_3  \
# 0                   30.0                   30.0                   31.0
# 1                 1905.0                   20.0                   20.0
# 2                   15.0                   30.0                   31.0
# 3                   15.0                   20.0                   20.0
# 4                    5.0                    5.0                   10.0
#
#       Широта    Долгота  Ипотека  Расстояние_до_Кремля  Окна_на_улицу  \
# 0  55.868713  37.456819        0             16.417191            NaN
# 1  55.770949  37.563930        0              3.971249            0.0
# 2  55.698791  37.468364        1             11.067722            NaN
# 3  55.683567  37.602962        0              7.665333            0.0
# 4  55.748071  37.540397        0              4.859495            NaN
#
#    Окна_во_двор  Окна_на_солнечную_сторону  Мебель_спальные_места  \
# 0           NaN                        NaN                    NaN
# 1           1.0                        0.0                    NaN
# 2           NaN                        NaN                    NaN
# 3           1.0                        1.0                    1.0
# 4           NaN                        NaN                    NaN
#
#    Мебель_кухня  Мебель_хранение_одежды  В_доме_мусоропровод  В_доме_консьерж  \
# 0           NaN                     NaN                  NaN              NaN
# 1           NaN                     NaN                  NaN              NaN
# 2           NaN                     NaN                  0.0              1.0
# 3           0.0                     0.0                  1.0              0.0
# 4           NaN                     NaN                  NaN              NaN
#
#    В_доме_газ  Двор_закрытая_территория  Двор_спортивная_площадка  \
# 0         NaN                       NaN                       NaN
# 1         NaN                       NaN                       NaN
# 2         0.0                       1.0                       1.0
# 3         0.0                       0.0                       1.0
# 4         NaN                       NaN                       NaN
#
#    Двор_детская_площадка  Парковка  Количество_лифтов       Цена_квм  \
# 0                    NaN       0.0                  0  450819.672131
# 1                    NaN       0.0                  0  529172.320217
# 2                    1.0       1.0                  4  324675.324675
# 3                    1.0       1.0                  1  286400.000000
# 4                    NaN       0.0                  1  557502.389296
#
#                  Район  Общий_рейтинг  Экология  Чистота   ЖКХ  Соседи  \
# 0         Левобережный           39.0      39.0     84.0  65.0    38.0
# 1          Пресненский           62.0      93.0     45.0  67.0    16.0
# 2  Очаково-Матвеевское           93.0      76.0     62.0  62.0    76.0
# 3             Котловка           53.0      36.0     22.0  53.0    78.0
# 4          Пресненский           62.0      93.0     45.0  67.0    16.0
#
#    Условия_для_детей  Спорт_и_отдых  Магазины  Транспорт  Безопасность  \
# 0               44.0           40.0     102.0       81.0          17.0
# 1               85.0           52.0     109.0       40.0          10.0
# 2               88.0          112.0      96.0      107.0          77.0
# 3               62.0           71.0      37.0       16.0          47.0
# 4               85.0           52.0     109.0       40.0          10.0
#
#    Стоимость_жизни  Суммарный рейтинг  Общая_площадь_отн_мин  \
# 0             23.0              572.0               1.763855
# 1             79.0              658.0               1.775904
# 2             94.0              943.0               1.669880
# 3            113.0              588.0               1.506024
# 4             79.0              658.0               2.831329
#
#    Общая_площадь_минус_мин  Общая_площадь_отн_макс  Общая_площадь_минус_макс  \
# 0                     31.7                0.281538                    -186.8
# 1                     32.2                0.283462                    -186.3
# 2                     27.8                0.266538                    -190.7
# 3                     21.0                0.240385                    -197.5
# 4                    609.1                1.000000                       0.0
#
#    Общая_площадь_отн_сред  Общая_площадь_минус_сред  \
# 0                0.873901                -10.562326
# 1                0.879871                -10.062326
# 2                0.827341                -14.462326
# 3                0.746159                -21.262326
# 4                1.798816                418.188889
#
#    Расстояние_до_Парк_культуры  Расстояние_до_Октябрьская  \
# 0                    17.083389                  18.258180
# 1                     4.329917                   5.493617
# 2                     8.955781                   9.558359
# 3                     5.869496                   5.106472
# 4                     3.666906                   4.892250
#
#    Расстояние_до_Добрынинская  Расстояние_до_Павелецкая  \
# 0                   18.672102                 19.183695
# 1                    5.934142                  6.548749
# 2                   10.224293                 11.210438
# 3                    5.197940                  5.601104
# 4                    5.562060                  6.482001
#
#    Расстояние_до_Таганская  Расстояние_до_Красные_ворота  \
# 0                18.657365                     16.339909
# 1                 6.432229                      5.254251
# 2                12.558108                     13.636461
# 3                 7.262720                      9.832084
# 4                 7.096690                      7.086697
#
#    Расстояние_до_Проспект_Мира  Расстояние_до_Курская  \
# 0                    14.839579              17.596692
# 1                     4.464546               6.107069
# 2                    13.702383              13.664497
# 3                    10.848071               9.048621
# 4                     6.805067               7.515234
#
#    Расстояние_до_Белорусская  Расстояние_до_Новослободская  \
# 0                  12.816081                     13.400078
# 1                   1.346540                      2.524840
# 2                  11.277326                     12.245417
# 3                  10.519448                     10.679586
# 4                   4.180065                      5.175824
#
#    Расстояние_до_Киевская  Расстояние_до_Краснопресненская  \
# 0               15.492292                        14.198571
# 1                3.094803                         1.435916
# 2                7.763103                         9.657269
# 3                7.054251                         8.693040
# 4                1.584375                         2.674213
#
#    Общая_площадь_кластер  Координаты_кластер
# 0                      8                  40
# 1                      8                 124
# 2                      8                  11
# 3                      0                  10
# 4                      9                  35

# %% [markdown]
# ### 2.1 Кодирование станций метро

# %%
metro_stations = np.append(metros['Станция'].values, ['нет'])

le = LabelEncoder()

le.fit(metro_stations.reshape(-1, 1))
for i in range(1, 4):
    df[f'Метро_{i}'] = le.transform(df[f'Метро_{i}'])

# %% [markdown]
# ### 2.2 Кодирование категориальных переменных

# %%
cat_features = [
    'Количество_комнат', 'Балкон_или_лоджия', 'Тип_комнат', 'Санузел',
    'Ремонт', 'Тип_дома', 'Район', 'Ипотека', 'Окна_во_двор',
    'Окна_на_солнечную_сторону', 'Окна_на_улицу', 'Мебель_спальные_места',
    'Мебель_кухня', 'Мебель_хранение_одежды', 'В_доме_консьерж',
    'В_доме_мусоропровод', 'В_доме_газ', 'Двор_детская_площадка',
    'Двор_закрытая_территория', 'Двор_спортивная_площадка', 'Парковка'
]

encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
df[cat_features] = encoder.fit_transform(df[cat_features])

# %% [markdown]
# ### 2.3 Отложенная выборка

# %%
train, test = train_test_split(df,
                               test_size=TEST_SIZE,
                               stratify=df['Количество_комнат'],
                               random_state=RANDOM_STATE)
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %% [markdown]
# ## 3 Вспомогательные функции

# %% [markdown]
# ### 3.1 Функция для обучения модели

# %%
def lgb_training(train_df, params, features, test_df=None, verbose=250):
    """
    Функция для обучения модели.
    
    Параметры
    ----------
    train_df - обучающая выборка
    params - набор гиперпараметров
    features - признаки
    test_df - тестовая выборка
    verbose - вывод результатов
    
    Возвращает
    -------
    score_list - MAPE на кросс-валидации для каждого фолда
    test_preds - предсказания на тестовой выборке, если тестовая выборка задана
    oof_preds - предсказания для обучающей выборки
    """
    test_preds = []
    if test_df is not None:
        test_preds = np.zeros(len(test_df))
        test_df = test_df[features]
    target = train_df.loc[:, TARGET_NAME].values

    categorical_feature = list(set(features) & set(cat_features))
    score_list = []
    oof_preds = np.zeros(len(target))

    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    for fold, (train_index, val_index) in enumerate(kf.split(train_df)):
        X_train = train_df.loc[train_index, features]
        X_val = train_df.loc[val_index, features]
        y_train = target[train_index]
        y_val = target[val_index]

        lgb_train = lgb.Dataset(X_train,
                                y_train,
                                categorical_feature=categorical_feature)
        lgb_valid = lgb.Dataset(X_val,
                                y_val,
                                categorical_feature=categorical_feature)

        callbacks = [lgb.log_evaluation(period=verbose)]
        model = lgb.train(params=params,
                          train_set=lgb_train,
                          num_boost_round=15000,
                          valid_sets=[lgb_train, lgb_valid],
                          categorical_feature=categorical_feature,
                          callbacks=callbacks)

        preds = model.predict(X_val)
        oof_preds[val_index] = preds
        score = mean_absolute_percentage_error(y_val, preds)

        if test_df is not None:
            test_preds += model.predict(test_df) / kf.n_splits

        if verbose:
            print(
                f"{Fore.BLACK}{Style.BRIGHT}FOLD: {fold}, MAPE: {score:.5f} {Style.RESET_ALL}"
            )
        score_list.append(score)

    return score_list, test_preds, oof_preds

# %% [markdown]
# ### 3.2 Функция для получения permutation importance
# [Источник](https://www.kaggle.com/code/simakov/keras-multilabel-neural-network-v1-2)

# %%
def iter_shuffled(X,
                  columns_to_shuffle=None,
                  pre_shuffle=False,
                  random_state=None):
    rng = check_random_state(random_state)

    if columns_to_shuffle is None:
        columns_to_shuffle = range(X.shape[1])

    if pre_shuffle:
        X_shuffled = X.copy()
        rng.shuffle(X_shuffled)

    X_res = X.copy()
    for columns in columns_to_shuffle:
        if pre_shuffle:
            X_res[:, columns] = X_shuffled[:, columns]
        else:
            rng.shuffle(X_res[:, columns])
        yield X_res
        X_res[:, columns] = X[:, columns]


def get_score_importances(score_func,
                          X,
                          y,
                          n_iter=5,
                          columns_to_shuffle=None,
                          random_state=None):
    rng = check_random_state(random_state)
    base_score = score_func(X, y)
    scores_decreases = []
    for i in trange(n_iter):
        scores_shuffled = _get_scores_shufled(
            score_func,
            X,
            y,
            columns_to_shuffle=columns_to_shuffle,
            random_state=rng,
            base_score=base_score)
        scores_decreases.append(scores_shuffled)

    return base_score, scores_decreases


def _get_scores_shufled(score_func,
                        X,
                        y,
                        base_score,
                        columns_to_shuffle=None,
                        random_state=None):
    Xs = iter_shuffled(X, columns_to_shuffle, random_state=random_state)
    res = []
    for X_shuffled in Xs:
        res.append(-score_func(X_shuffled, y) + base_score)
    return res

# %% [markdown]
# ## 4 Отбор признаков

# %%
features_to_drop = ['ID', 'Ссылка', 'Цена', 'Дата', 'Адрес', 'Цена_квм']
features = [f for f in df.columns if f not in features_to_drop]

# %%
params = {
    'objective': 'mape',
    'learning_rate': 0.3,
    'reg_lambda': 5,
    'random_state': 42,
    'early_stopping_rounds': 300,
    'feature_fraction': 0.4,
    'verbose': -1
}

# %%
perm_imp = np.zeros(len(features))
all_res = []
perm_df = pd.DataFrame({'feature': features})
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for fold, (train_index, val_index) in enumerate(kf.split(train)):
    print(f'Fold {fold}')

    X_train = train.loc[train_index, features]
    X_val = train.loc[val_index, features]
    y_train = train.loc[train_index, TARGET_NAME]
    y_val = train.loc[val_index, TARGET_NAME]

    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_valid = lgb.Dataset(X_val, y_val)

    callbacks = [lgb.log_evaluation(period=0)]
    model = lgb.train(params=params,
                      train_set=lgb_train,
                      num_boost_round=15000,
                      valid_sets=[lgb_train, lgb_valid],
                      categorical_feature=cat_features,
                      callbacks=callbacks)

    def _score(X, y):
        pred = model.predict(X)
        return mean_absolute_percentage_error(y, pred)

    base_score, local_imp = get_score_importances(_score,
                                                  X_val.values,
                                                  y_val.values,
                                                  n_iter=25,
                                                  random_state=RANDOM_STATE)
    all_res.append(local_imp)
    perm_imp += np.mean(local_imp, axis=0)
    perm_df[f"fold_{fold}_importance"] = perm_imp
    print('')
# Out:
# Fold 0
# 100%|██████████| 25/25 [08:37<00:00, 20.71s/it]
# Fold 1
# 100%|██████████| 25/25 [18:34<00:00, 44.59s/it]
# Fold 2
# 100%|██████████| 25/25 [27:31<00:00, 66.07s/it]
# Fold 3
# 100%|██████████| 25/25 [36:48<00:00, 88.32s/it]
# Fold 4
# 100%|██████████| 25/25 [16:14<00:00, 38.98s/it]

# %% [markdown]
# ## 5 Результаты

# %%
perm_df['importance'] = perm_df.filter(regex='^fold').mean(axis=1)
perm_df = perm_df.sort_values(by='importance')
best_feats = perm_df.sort_values(by='importance')['feature'].values
perm_df[perm_df['importance'] < 0]
# Out:
#                             feature  fold_0_importance  fold_1_importance  \
# 39                            Район          -0.072606          -0.155049
# 9                            Ремонт          -0.019788          -0.038830
# 12                    Этажей_в_доме          -0.012171          -0.025392
# 69  Расстояние_до_Краснопресненская          -0.008042          -0.021744
# 11                    Год_постройки          -0.011889          -0.022864
# 10                         Тип_дома          -0.008222          -0.018191
# 24             Расстояние_до_Кремля          -0.010699          -0.018962
# 68           Расстояние_до_Киевская          -0.004054          -0.011340
# 53          Общая_площадь_минус_мин          -0.006324          -0.013349
# 5                     Жилая_площадь          -0.006271          -0.011906
# 0                              Этаж          -0.005138          -0.010843
# 6                     Площадь_кухни          -0.003515          -0.008836
# 4                     Общая_площадь          -0.005603          -0.009815
# 58      Расстояние_до_Парк_культуры          -0.002860          -0.008952
# 7                   Высота_потолков          -0.003953          -0.008806
# 18            Расстояние_до_метро_1          -0.003342          -0.007512
# 34         Двор_закрытая_территория          -0.003185          -0.008117
# 8                           Санузел          -0.002926          -0.006219
# 65            Расстояние_до_Курская          -0.006162          -0.007243
# 55         Общая_площадь_минус_макс          -0.001945          -0.003983
# 66        Расстояние_до_Белорусская          -0.001629          -0.003851
# 60       Расстояние_до_Добрынинская          -0.001555          -0.005800
# 62          Расстояние_до_Таганская          -0.002077          -0.004386
# 64      Расстояние_до_Проспект_Мира          -0.002624          -0.003909
# 63     Расстояние_до_Красные_ворота          -0.003642          -0.004810
# 22                          Долгота          -0.001456          -0.004147
# 23                          Ипотека          -0.001518          -0.003155
# 33                       В_доме_газ          -0.001838          -0.003600
# 67     Расстояние_до_Новослободская          -0.002067          -0.003121
# 59        Расстояние_до_Октябрьская          -0.001196          -0.002946
# 57         Общая_площадь_минус_сред          -0.002059          -0.003270
# 29                     Мебель_кухня          -0.001461          -0.003458
# 32                  В_доме_консьерж          -0.001820          -0.002622
# 2                 Балкон_или_лоджия          -0.001456          -0.002737
# 15                          Метро_1          -0.001872          -0.003288
# 17                          Метро_3          -0.001394          -0.003035
# 26                     Окна_во_двор          -0.001272          -0.002892
# 38                Количество_лифтов          -0.001581          -0.002528
# 61         Расстояние_до_Павелецкая          -0.000745          -0.003293
# 16                          Метро_2          -0.001050          -0.002392
# 56           Общая_площадь_отн_сред          -0.000811          -0.002274
# 27        Окна_на_солнечную_сторону          -0.000693          -0.001706
# 54           Общая_площадь_отн_макс          -0.000999          -0.001772
# 21                           Широта          -0.000261          -0.001359
# 52            Общая_площадь_отн_мин          -0.001070          -0.002043
# 71               Координаты_кластер          -0.000832          -0.002097
# 1                 Количество_комнат          -0.000589          -0.002173
# 36            Двор_детская_площадка          -0.000662          -0.001248
# 25                    Окна_на_улицу          -0.001007          -0.001870
# 70            Общая_площадь_кластер          -0.000896          -0.001758
# 19            Расстояние_до_метро_2          -0.000869          -0.001735
# 46                    Спорт_и_отдых          -0.001147          -0.001569
# 13                Пассажирский_лифт          -0.000805          -0.001333
# 49                     Безопасность          -0.000728          -0.001554
# 40                    Общий_рейтинг          -0.000550          -0.001224
# 20            Расстояние_до_метро_3          -0.000147          -0.001133
# 14                    Грузовой_лифт          -0.000629          -0.001221
# 47                         Магазины          -0.000771          -0.001008
# 31              В_доме_мусоропровод          -0.000344          -0.001126
# 28            Мебель_спальные_места          -0.000269          -0.000683
# 48                        Транспорт          -0.000572          -0.000993
# 44                           Соседи          -0.000351          -0.000755
# 51                Суммарный рейтинг          -0.000539          -0.000829
# 41                         Экология          -0.000234          -0.000844
# 3                        Тип_комнат          -0.000061          -0.000673
# 35         Двор_спортивная_площадка          -0.000517          -0.000640
# 43                              ЖКХ          -0.000351          -0.000544
# 50                  Стоимость_жизни          -0.000234          -0.000630
# 45                Условия_для_детей          -0.000227          -0.000526
# 30           Мебель_хранение_одежды          -0.000403          -0.000561
# 42                          Чистота          -0.000316          -0.000427
# 37                         Парковка          -0.000280          -0.000542
#
#     fold_2_importance  fold_3_importance  fold_4_importance  importance
# 39          -0.230344          -0.316836          -0.397648   -0.234497
# 9           -0.059197          -0.081384          -0.101081   -0.060056
# 12          -0.039578          -0.055331          -0.068704   -0.040235
# 69          -0.039967          -0.047869          -0.058259   -0.035176
# 11          -0.034603          -0.044560          -0.058231   -0.034429
# 10          -0.029477          -0.040608          -0.050773   -0.029454
# 24          -0.022290          -0.033554          -0.042598   -0.025620
# 68          -0.021483          -0.033489          -0.044497   -0.022973
# 53          -0.019309          -0.025965          -0.032894   -0.019568
# 5           -0.019352          -0.024299          -0.032072   -0.018780
# 0           -0.017665          -0.023591          -0.029975   -0.017443
# 6           -0.016047          -0.022712          -0.028079   -0.015838
# 4           -0.014223          -0.019496          -0.026067   -0.015041
# 58          -0.016352          -0.020341          -0.024258   -0.014553
# 7           -0.012579          -0.017372          -0.023193   -0.013180
# 18          -0.012402          -0.016189          -0.020453   -0.011980
# 34          -0.011177          -0.013929          -0.017908   -0.010863
# 8           -0.009193          -0.011333          -0.014314   -0.008797
# 65          -0.008404          -0.009133          -0.009969   -0.008182
# 55          -0.007469          -0.011141          -0.013187   -0.007545
# 66          -0.008216          -0.010002          -0.011147   -0.006969
# 60          -0.006381          -0.008295          -0.012293   -0.006865
# 62          -0.005672          -0.007960          -0.009800   -0.005979
# 64          -0.005496          -0.006764          -0.010604   -0.005879
# 63          -0.005901          -0.006858          -0.008107   -0.005864
# 22          -0.006199          -0.007570          -0.009421   -0.005759
# 23          -0.005432          -0.007681          -0.010795   -0.005716
# 33          -0.006247          -0.007190          -0.009266   -0.005628
# 67          -0.004004          -0.008620          -0.009907   -0.005544
# 59          -0.005298          -0.007315          -0.010644   -0.005480
# 57          -0.004647          -0.006888          -0.009528   -0.005279
# 29          -0.004840          -0.006666          -0.008537   -0.004992
# 32          -0.004085          -0.006879          -0.009179   -0.004917
# 2           -0.004958          -0.006986          -0.007985   -0.004824
# 15          -0.004633          -0.005979          -0.006991   -0.004553
# 17          -0.004516          -0.006329          -0.007351   -0.004525
# 26          -0.004258          -0.006023          -0.007667   -0.004422
# 38          -0.004386          -0.005534          -0.006751   -0.004156
# 61          -0.004636          -0.005677          -0.006416   -0.004153
# 16          -0.003886          -0.005366          -0.006560   -0.003851
# 56          -0.004052          -0.004856          -0.006695   -0.003737
# 27          -0.002926          -0.004826          -0.005699   -0.003170
# 54          -0.003004          -0.004214          -0.005360   -0.003070
# 21          -0.002599          -0.004462          -0.005514   -0.002839
# 52          -0.002832          -0.003600          -0.004588   -0.002827
# 71          -0.002911          -0.003704          -0.004319   -0.002773
# 1           -0.002556          -0.003453          -0.004888   -0.002732
# 36          -0.002343          -0.003489          -0.004142   -0.002377
# 25          -0.002202          -0.003222          -0.003580   -0.002376
# 70          -0.002174          -0.002748          -0.004211   -0.002358
# 19          -0.002269          -0.002852          -0.003801   -0.002305
# 46          -0.001981          -0.003003          -0.003670   -0.002274
# 13          -0.001751          -0.002873          -0.003189   -0.001990
# 49          -0.002140          -0.002619          -0.002806   -0.001969
# 40          -0.001909          -0.002197          -0.002597   -0.001695
# 20          -0.001797          -0.002232          -0.002674   -0.001597
# 14          -0.001509          -0.001970          -0.002477   -0.001561
# 47          -0.001465          -0.001870          -0.002157   -0.001454
# 31          -0.001338          -0.001737          -0.001809   -0.001271
# 28          -0.001019          -0.001632          -0.002503   -0.001221
# 48          -0.001263          -0.001407          -0.001789   -0.001205
# 44          -0.000924          -0.001554          -0.001925   -0.001102
# 51          -0.001215          -0.001256          -0.001651   -0.001098
# 41          -0.001168          -0.001482          -0.001737   -0.001093
# 3           -0.001227          -0.001663          -0.001838   -0.001092
# 35          -0.001177          -0.001340          -0.001524   -0.001039
# 43          -0.000932          -0.001460          -0.001774   -0.001012
# 50          -0.001054          -0.001230          -0.001681   -0.000966
# 45          -0.000897          -0.001123          -0.001615   -0.000877
# 30          -0.000786          -0.001037          -0.001353   -0.000828
# 42          -0.000870          -0.001090          -0.001277   -0.000796
# 37          -0.000666          -0.000962          -0.001205   -0.000731

# %% [markdown]
# Самым важным признаком оказался район, его перемешивание увеличивает ошибку в среднем на 0.23

# %% [markdown]
# Попробуем найти лучшую комбинацию признаков в количестве менее 35 штук

# %%
result_df = pd.DataFrame(columns=['features', 'score'])
for i in trange(5, 36):
    current_feats = best_feats[:i]
    score_list, _, _ = lgb_training(train, params, current_feats, verbose=0)
    result_df = result_df.append(
        {
            'features': current_feats,
            'score': np.mean(score_list)
        },
        ignore_index=True)
# Out:
# 100%|██████████| 31/31 [1:45:07<00:00, 203.48s/it]

# %%
result_df = result_df.sort_values(by='score')
display(result_df.head(10))
display(result_df.head(10)['features'].values)
# Out:
#                                              features     score
# 29  [Район, Ремонт, Этажей_в_доме, Расстояние_до_К...  0.123427
# 30  [Район, Ремонт, Этажей_в_доме, Расстояние_до_К...  0.124134
# 25  [Район, Ремонт, Этажей_в_доме, Расстояние_до_К...  0.124179
# 28  [Район, Ремонт, Этажей_в_доме, Расстояние_до_К...  0.124258
# 27  [Район, Ремонт, Этажей_в_доме, Расстояние_до_К...  0.124532
# 22  [Район, Ремонт, Этажей_в_доме, Расстояние_до_К...  0.124864
# 21  [Район, Ремонт, Этажей_в_доме, Расстояние_до_К...  0.125106
# 24  [Район, Ремонт, Этажей_в_доме, Расстояние_до_К...  0.125502
# 16  [Район, Ремонт, Этажей_в_доме, Расстояние_до_К...  0.125641
# 23  [Район, Ремонт, Этажей_в_доме, Расстояние_до_К...  0.125690
# array([array(['Район', 'Ремонт', 'Этажей_в_доме',
#               'Расстояние_до_Краснопресненская', 'Год_постройки', 'Тип_дома',
#               'Расстояние_до_Кремля', 'Расстояние_до_Киевская',
#               'Общая_площадь_минус_мин', 'Жилая_площадь', 'Этаж',
#               'Площадь_кухни', 'Общая_площадь', 'Расстояние_до_Парк_культуры',
#               'Высота_потолков', 'Расстояние_до_метро_1',
#               'Двор_закрытая_территория', 'Санузел', 'Расстояние_до_Курская',
#               'Общая_площадь_минус_макс', 'Расстояние_до_Белорусская',
#               'Расстояние_до_Добрынинская', 'Расстояние_до_Таганская',
#               'Расстояние_до_Проспект_Мира', 'Расстояние_до_Красные_ворота',
#               'Долгота', 'Ипотека', 'В_доме_газ', 'Расстояние_до_Новослободская',
#               'Расстояние_до_Октябрьская', 'Общая_площадь_минус_сред',
#               'Мебель_кухня', 'В_доме_консьерж', 'Балкон_или_лоджия'],
#              dtype=object)                                                       ,
#        array(['Район', 'Ремонт', 'Этажей_в_доме',
#               'Расстояние_до_Краснопресненская', 'Год_постройки', 'Тип_дома',
#               'Расстояние_до_Кремля', 'Расстояние_до_Киевская',
#               'Общая_площадь_минус_мин', 'Жилая_площадь', 'Этаж',
#               'Площадь_кухни', 'Общая_площадь', 'Расстояние_до_Парк_культуры',
#               'Высота_потолков', 'Расстояние_до_метро_1',
#               'Двор_закрытая_территория', 'Санузел', 'Расстояние_до_Курская',
#               'Общая_площадь_минус_макс', 'Расстояние_до_Белорусская',
#               'Расстояние_до_Добрынинская', 'Расстояние_до_Таганская',
#               'Расстояние_до_Проспект_Мира', 'Расстояние_до_Красные_ворота',
#               'Долгота', 'Ипотека', 'В_доме_газ', 'Расстояние_до_Новослободская',
#               'Расстояние_до_Октябрьская', 'Общая_площадь_минус_сред',
#               'Мебель_кухня', 'В_доме_консьерж', 'Балкон_или_лоджия', 'Метро_1'],
#              dtype=object)                                                       ,
#        array(['Район', 'Ремонт', 'Этажей_в_доме',
#               'Расстояние_до_Краснопресненская', 'Год_постройки', 'Тип_дома',
#               'Расстояние_до_Кремля', 'Расстояние_до_Киевская',
#               'Общая_площадь_минус_мин', 'Жилая_площадь', 'Этаж',
#               'Площадь_кухни', 'Общая_площадь', 'Расстояние_до_Парк_культуры',
#               'Высота_потолков', 'Расстояние_до_метро_1',
#               'Двор_закрытая_территория', 'Санузел', 'Расстояние_до_Курская',
#               'Общая_площадь_минус_макс', 'Расстояние_до_Белорусская',
#               'Расстояние_до_Добрынинская', 'Расстояние_до_Таганская',
#               'Расстояние_до_Проспект_Мира', 'Расстояние_до_Красные_ворота',
#               'Долгота', 'Ипотека', 'В_доме_газ', 'Расстояние_до_Новослободская',
#               'Расстояние_до_Октябрьская'], dtype=object)                        ,
#        array(['Район', 'Ремонт', 'Этажей_в_доме',
#               'Расстояние_до_Краснопресненская', 'Год_постройки', 'Тип_дома',
#               'Расстояние_до_Кремля', 'Расстояние_до_Киевская',
#               'Общая_площадь_минус_мин', 'Жилая_площадь', 'Этаж',
#               'Площадь_кухни', 'Общая_площадь', 'Расстояние_до_Парк_культуры',
#               'Высота_потолков', 'Расстояние_до_метро_1',
#               'Двор_закрытая_территория', 'Санузел', 'Расстояние_до_Курская',
#               'Общая_площадь_минус_макс', 'Расстояние_до_Белорусская',
#               'Расстояние_до_Добрынинская', 'Расстояние_до_Таганская',
#               'Расстояние_до_Проспект_Мира', 'Расстояние_до_Красные_ворота',
#               'Долгота', 'Ипотека', 'В_доме_газ', 'Расстояние_до_Новослободская',
#               'Расстояние_до_Октябрьская', 'Общая_площадь_минус_сред',
#               'Мебель_кухня', 'В_доме_консьерж'], dtype=object)                  ,
#        array(['Район', 'Ремонт', 'Этажей_в_доме',
#               'Расстояние_до_Краснопресненская', 'Год_постройки', 'Тип_дома',
#               'Расстояние_до_Кремля', 'Расстояние_до_Киевская',
#               'Общая_площадь_минус_мин', 'Жилая_площадь', 'Этаж',
#               'Площадь_кухни', 'Общая_площадь', 'Расстояние_до_Парк_культуры',
#               'Высота_потолков', 'Расстояние_до_метро_1',
#               'Двор_закрытая_территория', 'Санузел', 'Расстояние_до_Курская',
#               'Общая_площадь_минус_макс', 'Расстояние_до_Белорусская',
#               'Расстояние_до_Добрынинская', 'Расстояние_до_Таганская',
#               'Расстояние_до_Проспект_Мира', 'Расстояние_до_Красные_ворота',
#               'Долгота', 'Ипотека', 'В_доме_газ', 'Расстояние_до_Новослободская',
#               'Расстояние_до_Октябрьская', 'Общая_площадь_минус_сред',
#               'Мебель_кухня'], dtype=object)                                     ,
#        array(['Район', 'Ремонт', 'Этажей_в_доме',
#               'Расстояние_до_Краснопресненская', 'Год_постройки', 'Тип_дома',
#               'Расстояние_до_Кремля', 'Расстояние_до_Киевская',
#               'Общая_площадь_минус_мин', 'Жилая_площадь', 'Этаж',
#               'Площадь_кухни', 'Общая_площадь', 'Расстояние_до_Парк_культуры',
#               'Высота_потолков', 'Расстояние_до_метро_1',
#               'Двор_закрытая_территория', 'Санузел', 'Расстояние_до_Курская',
#               'Общая_площадь_минус_макс', 'Расстояние_до_Белорусская',
#               'Расстояние_до_Добрынинская', 'Расстояние_до_Таганская',
#               'Расстояние_до_Проспект_Мира', 'Расстояние_до_Красные_ворота',
#               'Долгота', 'Ипотека'], dtype=object)                            ,
#        array(['Район', 'Ремонт', 'Этажей_в_доме',
#               'Расстояние_до_Краснопресненская', 'Год_постройки', 'Тип_дома',
#               'Расстояние_до_Кремля', 'Расстояние_до_Киевская',
#               'Общая_площадь_минус_мин', 'Жилая_площадь', 'Этаж',
#               'Площадь_кухни', 'Общая_площадь', 'Расстояние_до_Парк_культуры',
#               'Высота_потолков', 'Расстояние_до_метро_1',
#               'Двор_закрытая_территория', 'Санузел', 'Расстояние_до_Курская',
#               'Общая_площадь_минус_макс', 'Расстояние_до_Белорусская',
#               'Расстояние_до_Добрынинская', 'Расстояние_до_Таганская',
#               'Расстояние_до_Проспект_Мира', 'Расстояние_до_Красные_ворота',
#               'Долгота'], dtype=object)                                       ,
#        array(['Район', 'Ремонт', 'Этажей_в_доме',
#               'Расстояние_до_Краснопресненская', 'Год_постройки', 'Тип_дома',
#               'Расстояние_до_Кремля', 'Расстояние_до_Киевская',
#               'Общая_площадь_минус_мин', 'Жилая_площадь', 'Этаж',
#               'Площадь_кухни', 'Общая_площадь', 'Расстояние_до_Парк_культуры',
#               'Высота_потолков', 'Расстояние_до_метро_1',
#               'Двор_закрытая_территория', 'Санузел', 'Расстояние_до_Курская',
#               'Общая_площадь_минус_макс', 'Расстояние_до_Белорусская',
#               'Расстояние_до_Добрынинская', 'Расстояние_до_Таганская',
#               'Расстояние_до_Проспект_Мира', 'Расстояние_до_Красные_ворота',
#               'Долгота', 'Ипотека', 'В_доме_газ', 'Расстояние_до_Новослободская'],
#              dtype=object)                                                        ,
#        array(['Район', 'Ремонт', 'Этажей_в_доме',
#               'Расстояние_до_Краснопресненская', 'Год_постройки', 'Тип_дома',
#               'Расстояние_до_Кремля', 'Расстояние_до_Киевская',
#               'Общая_площадь_минус_мин', 'Жилая_площадь', 'Этаж',
#               'Площадь_кухни', 'Общая_площадь', 'Расстояние_до_Парк_культуры',
#               'Высота_потолков', 'Расстояние_до_метро_1',
#               'Двор_закрытая_территория', 'Санузел', 'Расстояние_до_Курская',
#               'Общая_площадь_минус_макс', 'Расстояние_до_Белорусская'],
#              dtype=object)                                                    ,
#        array(['Район', 'Ремонт', 'Этажей_в_доме',
#               'Расстояние_до_Краснопресненская', 'Год_постройки', 'Тип_дома',
#               'Расстояние_до_Кремля', 'Расстояние_до_Киевская',
#               'Общая_площадь_минус_мин', 'Жилая_площадь', 'Этаж',
#               'Площадь_кухни', 'Общая_площадь', 'Расстояние_до_Парк_культуры',
#               'Высота_потолков', 'Расстояние_до_метро_1',
#               'Двор_закрытая_территория', 'Санузел', 'Расстояние_до_Курская',
#               'Общая_площадь_минус_макс', 'Расстояние_до_Белорусская',
#               'Расстояние_до_Добрынинская', 'Расстояние_до_Таганская',
#               'Расстояние_до_Проспект_Мира', 'Расстояние_до_Красные_ворота',
#               'Долгота', 'Ипотека', 'В_доме_газ'], dtype=object)              ],
#       dtype=object)
